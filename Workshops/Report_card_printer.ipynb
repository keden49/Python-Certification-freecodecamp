# %% [markdown]
# # Project Overview
#  This workshop aims to generate a report cards printer for students, that validates the data types of various metrics

# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, float))
print(score,type(score))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# True
# 80.5 <class 'float'>
