# %% [markdown]
# # Debugging

# %%
import pdb
def validate_isbn(isbn, length):

    if len(isbn) != length:
        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code

    main_digits = isbn[0:length] #slices every digit
    given_check_digit = isbn[length-1] # I believe its going to be out of bounds

   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:
      pdb.set_trace()




      expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:

      expected_check_digit = calculate_check_digit_13(main_digits_list)

    # Add pdb.set_trace() here to inspect expected_check_digit and given_check_digit
    #pdb.set_trace()

    # Check if the given check digit matches with the calculated check digit
    if given_check_digit == expected_check_digit:
        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')



def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    pdb.set_trace()

    result = 11 - digits_sum % 11

    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.

    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit

def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.

    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results

    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit

    # Move this block outside of the calculate_check_digit_13 function and into validate_isbn
    # for it to be executed after the check digit is calculated.

def main():
    user_input = input('Enter ISBN and length: ')
    values = user_input.split(',')
    isbn = values[0]
    length = int(values[1])
    if length == 10 or length == 13:
     validate_isbn(isbn, length)
    else:
     print('Length should be 10 or 13.')

main()
# Out:
# Enter ISBN and length: 1530051126,10,
# > /tmp/ipython-input-361546551.py(20)validate_isbn()
#      18
#      19
# ---> 20       expected_check_digit = calculate_check_digit_10(main_digits_list)
#      21     else:
#      22
#
# ipdb> s
# --Call--
# > /tmp/ipython-input-361546551.py(36)calculate_check_digit_10()
#      34
#      35
# ---> 36 def calculate_check_digit_10(main_digits_list):
#      37     # Note: You don't have to fully understand the logic in this function.
#      38     digits_sum = 0
#
# ipdb> n
# > /tmp/ipython-input-361546551.py(38)calculate_check_digit_10()
#      36 def calculate_check_digit_10(main_digits_list):
#      37     # Note: You don't have to fully understand the logic in this function.
# ---> 38     digits_sum = 0
#      39     # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
#      40     for index, digit in enumerate(main_digits_list):
#
# ipdb> c
# > /tmp/ipython-input-361546551.py(45)calculate_check_digit_10()
#      43     pdb.set_trace()
#      44
# ---> 45     result = 11 - digits_sum % 11
#      46
#      47     # The calculation result can range from 1 to 11.
#
# ipdb> p result
# *** NameError: name 'result' is not defined
# ipdb> p result
# *** NameError: name 'result' is not defined
# ipdb> n
# > /tmp/ipython-input-361546551.py(52)calculate_check_digit_10()
#      50     # Use the value as it is for other numbers.
#      51
# ---> 52     if result == 11:
#      53         expected_check_digit = '0'
#      54     elif result == 10:
#
# ipdb> p result
# 11
# ipdb> p digits_sum
# 121
# ipdb> p expected_check_digit
# *** NameError: name 'expected_check_digit' is not defined
# ipdb> n
# > /tmp/ipython-input-361546551.py(53)calculate_check_digit_10()
#      51
#      52     if result == 11:
# ---> 53         expected_check_digit = '0'
#      54     elif result == 10:
#      55         expected_check_digit = 'X'
#
# ipdb> n
# > /tmp/ipython-input-361546551.py(58)calculate_check_digit_10()
#      56     else:
#      57         expected_check_digit = str(result)
# ---> 58     return expected_check_digit
#      59
#      60 def calculate_check_digit_13(main_digits_list):
#
# ipdb> n
# --Return--
# '0'
# > /tmp/ipython-input-361546551.py(58)calculate_check_digit_10()
#      56     else:
#      57         expected_check_digit = str(result)
# ---> 58     return expected_check_digit
#      59
#      60 def calculate_check_digit_13(main_digits_list):
#
# ipdb> p expected_check_digit
# '0'
# ipdb> c
# Invalid ISBN Code.

# %% [markdown]
# # Conclusion
# I noticed that the digits_sum came to 121 instead of 115 which returns a remainder of 5 which when subtrackted from 11 is 6 . This was because i was slicing the whole isnb string instead of only main string. This is due to index errors. The error was in this line main_digits = isbn[0:length] instead it should read as main_digits = isbn[0:length - 1]

# %% [markdown]
# # Running Tests
# # Test 1

# %%
import pdb
def validate_isbn(isbn, length):

    if len(isbn) != length:
        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code

    main_digits = isbn[0:length-1] #slices every digit
    given_check_digit = isbn[length-1] # I believe its going to be out of bounds

   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:
      pdb.set_trace()




      expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:

      expected_check_digit = calculate_check_digit_13(main_digits_list)

    # Add pdb.set_trace() here to inspect expected_check_digit and given_check_digit
    #pdb.set_trace()

    # Check if the given check digit matches with the calculated check digit
    if given_check_digit == expected_check_digit:
        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')



def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    pdb.set_trace()

    result = 11 - digits_sum % 11

    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.

    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit

def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.

    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results

    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit

    # Move this block outside of the calculate_check_digit_13 function and into validate_isbn
    # for it to be executed after the check digit is calculated.

def main():
    user_input = input('Enter ISBN and length: ')
    values = user_input.split(',')
    isbn = values[0]
    length = int(values[1])
    if length == 10 or length == 13:
     validate_isbn(isbn, length)
    else:
     print('Length should be 10 or 13.')

main()
# Out:
# Enter ISBN and length: 1530051126,10
# > /tmp/ipython-input-3716333089.py(20)validate_isbn()
#      18
#      19
# ---> 20       expected_check_digit = calculate_check_digit_10(main_digits_list)
#      21     else:
#      22
#
# ipdb> s
# --Call--
# > /tmp/ipython-input-3716333089.py(36)calculate_check_digit_10()
#      34
#      35
# ---> 36 def calculate_check_digit_10(main_digits_list):
#      37     # Note: You don't have to fully understand the logic in this function.
#      38     digits_sum = 0
#
# ipdb> c
# > /tmp/ipython-input-3716333089.py(44)calculate_check_digit_10()
#      42     # Find the remainder of dividing the sum by 11, then subtract it from 11
#      43     pdb.set_trace()
# ---> 44     result = 11 - digits_sum % 11
#      45
#      46     # The calculation result can range from 1 to 11.
#
# ipdb> n
# > /tmp/ipython-input-3716333089.py(50)calculate_check_digit_10()
#      48     # If the result is 10, use upper case X.
#      49     # Use the value as it is for other numbers.
# ---> 50     if result == 11:
#      51         expected_check_digit = '0'
#      52     elif result == 10:
#
# ipdb> p digits_sum
# 115
# ipdb> p_result
# *** NameError: name 'p_result' is not defined
# ipdb> p result
# 6
# ipdb> c
# Valid ISBN Code.

# %% [markdown]
# # Tests 2

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 1530051125,10
# Invalid ISBN Code.

# %% [markdown]
# # Tests 3

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 1530051126,13
# ISBN-13 code should be 13 digits long.

# %%
k = 'wert'
print(type(len(k)))
# Out:
# <class 'int'>

# %% [markdown]
# # Test 4

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
        return
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 15-0051126,10
# Invalid character was found.

# %% [markdown]
# # Test 5

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
        return
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 1530051126,9
# Length should be 10 or 13.

# %% [markdown]
# # Test 6

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
        return
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 1530051125,A
# Length must be a number.

# %% [markdown]
# # Test 7

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]
    try:
        if not isbn.isdigit():
            raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
        return
    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 1530051125
# Enter comma-separated values.

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]

def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]

    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 080442957X,10
# Valid ISBN Code.

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    try:
       if main_digits.isdigit():
        main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
       else:
        raise ValueError('Invalid character was found.')
    except ValueError as e:
        print(e)
        return








    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]

    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




main()
# Out:
# Enter ISBN and length: 15-0051126,10
# Invalid character was found.

# %% [markdown]
# # Final Code

# %%
def validate_isbn(isbn, length):
    if len(isbn) != length:

        print(f'ISBN-{length} code should be {length} digits long.')
        return #program crushes when isbn doesnt match length of code
    main_digits = isbn[0:length-1] #slices every digit
    #fixing the off by one error

    #correct indexerror
    given_check_digit = isbn[length - 1] # I believe its going to be out of bounds


   #list comprehension
    try:
       if main_digits.isdigit():
        main_digits_list = [int(digit) for digit in main_digits] #loop through string and convert each item into digit
       else:
        raise ValueError
    except ValueError:
        print('Invalid character was found.')
        return








    # Calculate the check digit from other digits
    if length == 10:

        expected_check_digit = calculate_check_digit_10(main_digits_list)
    else:
        expected_check_digit = calculate_check_digit_13(main_digits_list)
    # Check if the given check digit matches with the calculated check digit

    if given_check_digit == expected_check_digit:

        print('Valid ISBN Code.')
    else:
        print('Invalid ISBN Code.')
def calculate_check_digit_10(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 9 digits by its corresponding weight (10 to 2) and sum up the results
    for index, digit in enumerate(main_digits_list):
        digits_sum += digit * (10 - index)
    # Find the remainder of dividing the sum by 11, then subtract it from 11
    result = 11 - digits_sum % 11
    # The calculation result can range from 1 to 11.
    # If the result is 11, use 0.
    # If the result is 10, use upper case X.
    # Use the value as it is for other numbers.
    if result == 11:
        expected_check_digit = '0'
    elif result == 10:
        expected_check_digit = 'X'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def calculate_check_digit_13(main_digits_list):
    # Note: You don't have to fully understand the logic in this function.
    digits_sum = 0
    # Multiply each of the first 12 digits by 1 and 3 alternately (starting with 1), and sum up the results
    for index, digit in enumerate(main_digits_list):
        if index % 2 == 0:
            digits_sum += digit * 1
        else:
            digits_sum += digit * 3
    # Find the remainder of dividing the sum by 10, then subtract it from 10
    result = 10 - digits_sum % 10
    # The calculation result can range from 1 to 10.
    # If the result is 10, use 0.
    # Use the value as it is for other numbers.
    if result == 10:
        expected_check_digit = '0'
    else:
        expected_check_digit = str(result)
    return expected_check_digit
def main():

    user_input = input('Enter ISBN and length: ')



    values = user_input.split(',')

    isbn = values[0]

    try:
        length = int(values[1])
    except IndexError:
        print('Enter comma-separated values.')
        return
    except ValueError:
        print('Length must be a number.')
        return




    if length == 10 or length == 13:
        validate_isbn(isbn, length)

    else:
        print('Length should be 10 or 13.')




#main()

# %% [markdown]
# # Conclusion
# The  major mistakes was handling user invalid values eg entering a record that has other characters . I was attempting to handle the issue at the user entry point but this method was wrong since we havent sliced isbn into the check digit and the main digits which will be used to calculate the expected checked digit.  So the ValueError had to be handled at the processing main digits after data has already been collected.
