# %% [markdown]
# # Notebook Overview
#
# This notebook demonstrates tests and roughwork done during figuring out the fibonnaci sequence

# %% [markdown]
# # Logic
#
# The Fibonacci sequence is a classic example of dynamic programming because it contains overlapping subproblems; to find any number in the sequence, you must calculate the same smaller numbers over and over again
#
# ![image.png](data:image/png;base64,...)
#
# Definition: Dynamic programming is an algorithmic technique that solves complex problems by breaking them down into simpler subproblems and storing the results to avoid redundant calculations.

# %%
# applying logic

def fibonacci(n):#test 1,2

  # initializing sequence

  sequence = [0, 1] #test 3

  for i in range(2,n+1):
    # next number in a sequence is determined by the two preceding numbers before it
    next_no  = sequence[i-1] + sequence[i-2]
    sequence.append(next_no)

  return sequence[n] #test 11

# %%
# testing other logic

def fibonacci(n): #test 1,2

  # initializing sequence

  sequence = [0, 1]#test 3

  prev2,prev1 = sequence #unpacking list

  # storing values of only the last 2 previous values in the sequence
  # to be memory efficient

  if n == 0:
    return prev2

  for _ in range(2,n+1):
    next_no = prev1 + prev2
    prev2 = prev1
    prev1 = next_no

  return prev1 #test 11

# %%
fibonacci(5)
# Out:
# 5

# %% [markdown]
# # Tests
#
# 1. You should have a function named fibonacci.
# 2. Your fibonacci function should take a single parameter.
# 3. You should have a list named sequence within the fibonacci function initialized to [0, 1].
# 4. fibonacci(0) should return 0.
# 5. fibonacci(1) should return 1.
# 6. fibonacci(2) should return 1.
# 7. fibonacci(3) should return 2.
# 8. fibonacci(5) should return 5.
# 9. fibonacci(10) should return 55.
# 10. fibonacci(15) should return 610.
# 11. You should not use recursion in your code.

# %% [markdown]
# Test 4
#
# fibonacci(0) should return 0.

# %%
fibonacci(0)
# Out:
# 0

# %% [markdown]
# Test 5
#
# fibonacci(1) should return 1.

# %%
fibonacci(1)
# Out:
# 1

# %% [markdown]
# Test 6
#
# fibonacci(2) should return 1.

# %%
fibonacci(2)
# Out:
# 1

# %% [markdown]
# Test 7
#
# fibonacci(3) should return 2.

# %%
fibonacci(3)
# Out:
# 2

# %% [markdown]
# Test 8
#
# fibonacci(5) should return 5.

# %%
fibonacci(5)
# Out:
# 5

# %% [markdown]
# Test 9
#
# fibonacci(10) should return 55.

# %%
fibonacci(10)
# Out:
# 55

# %% [markdown]
# Test 10
#
# fibonacci(15) should return 610.

# %%
fibonacci(15)
# Out:
# 610
