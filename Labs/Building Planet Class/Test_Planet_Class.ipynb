# %% [markdown]
# # Tests
#
# Tests
# 1. You should create a class named Planet.
# 2. The Planet class should have an __init__ method.
# 3. The __init__ method should have four parameters: self, name, planet_type, and star, in this order.
# 4. The __init__ method should raise a TypeError with the message name, planet type, and star must be strings if the first argument passed in is not a string type.
# 5. The __init__ method should raise a TypeError with the message name, planet type, and star must be strings if the second argument passed in is not a string type.
# 6. The __init__ method should raise a TypeError with the message name, planet type, and star must be strings if the third argument passed in is not a string type.
# 7. The __init__ method should raise a ValueError with the message name, planet_type, and star must be non-empty strings if the first argument passed in is an empty string.
# 8. The __init__ method should raise a ValueError with the message name, planet_type, and star must be non-empty strings if the second argument passed in is an empty string.
# 9. The __init__ method should raise a ValueError with the message name, planet_type, and star must be non-empty strings if the third argument passed in is an empty string.
# 10. You should assign name to self.name in the __init__ method.
# 11. You should assign planet_type to self.planet_type in the __init__ method.
# 12. You should assign star to self.star in the __init__ method.
# 13. The Planet class should have an orbit method.
# 14. The orbit method should return a string in the format {name} is orbiting around {star}....
# 15. The Planet class should have a __str__ method.
# 16. The __str__ method should return a string in the format Planet: {name} | Type: {planet_type} | Star: {star}.
# 17. You should create three instances of the Planet class named planet_1, planet_2, and planet_3.
# 18. You should print each planet object to see the __str__ method output.
# 19. You should call the orbit method on each planet object and print the result

# %% [markdown]
# # Running Tests

# %% [markdown]
# # Test 1-3

# %%
# Test 1
class Planet: #creating empty class object
   #Test 2 $ 3
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# Planet: Earth | Type: Terrestrial | Star: Sun
# Planet: Jupiter | Type: Gas | Star: Sun
# Planet: Neptune | Type: Ice Giant | Star: Sun
# 0x7fdaedb5a9c0
# 0x7fdaed683a10
# 0x7fdaed682e10

# %% [markdown]
# # Test 4

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet(1,'Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3097111579.py in <cell line: 0>()
#      19
#      20
# ---> 21 planet_1 = Planet(1,'Terrestrial','Sun')
#      22 planet_2 = Planet('Jupiter','Gas','Sun')
#      23 planet_3 = Planet('Neptune','Ice Giant','Sun')
#
# /tmp/ipython-input-3097111579.py in __init__(self, name, planet_type, star)
#       2     def __init__(self,name,planet_type,star):#initializing instance
#       3         if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
# ----> 4             raise TypeError(f'name, planet type, and star must be strings')
#       5
#       6         #cehck if all variables are non-empty
#
# TypeError: name, planet type, and star must be strings

# %% [markdown]
# # Test 5

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth',2,'Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1349707450.py in <cell line: 0>()
#      19
#      20
# ---> 21 planet_1 = Planet('Earth',2,'Sun')
#      22 planet_2 = Planet('Jupiter','Gas','Sun')
#      23 planet_3 = Planet('Neptune','Ice Giant','Sun')
#
# /tmp/ipython-input-1349707450.py in __init__(self, name, planet_type, star)
#       2     def __init__(self,name,planet_type,star):#initializing instance
#       3         if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
# ----> 4             raise TypeError(f'name, planet type, and star must be strings')
#       5
#       6         #cehck if all variables are non-empty
#
# TypeError: name, planet type, and star must be strings

# %% [markdown]
# # Test 6

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas',3)
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2125873039.py in <cell line: 0>()
#      20
#      21 planet_1 = Planet('Earth','Terrestrial','Sun')
# ---> 22 planet_2 = Planet('Jupiter','Gas',3)
#      23 planet_3 = Planet('Neptune','Ice Giant','Sun')
#      24 #Print __str__ method
#
# /tmp/ipython-input-2125873039.py in __init__(self, name, planet_type, star)
#       2     def __init__(self,name,planet_type,star):#initializing instance
#       3         if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
# ----> 4             raise TypeError(f'name, planet type, and star must be strings')
#       5
#       6         #cehck if all variables are non-empty
#
# TypeError: name, planet type, and star must be strings

# %% [markdown]
# # Test 7

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1648693196.py in <cell line: 0>()
#      20
#      21 planet_1 = Planet('Earth','Terrestrial','Sun')
# ---> 22 planet_2 = Planet('','Gas','Sun')
#      23 planet_3 = Planet('Neptune','Ice Giant','Sun')
#      24 #Print __str__ method
#
# /tmp/ipython-input-1648693196.py in __init__(self, name, planet_type, star)
#       6         #cehck if all variables are non-empty
#       7         elif not all([name,planet_type,star]):
# ----> 8             raise ValueError('name, planet_type, and star must be non-empty strings')
#       9         else:
#      10             self.name = name
#
# ValueError: name, planet_type, and star must be non-empty strings

# %% [markdown]
# # Test 8

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-305461377.py in <cell line: 0>()
#      21 planet_1 = Planet('Earth','Terrestrial','Sun')
#      22 planet_2 = Planet('Jupiter','Gas','Sun')
# ---> 23 planet_3 = Planet('Neptune','','Sun')
#      24 #Print __str__ method
#      25 print(planet_1)
#
# /tmp/ipython-input-305461377.py in __init__(self, name, planet_type, star)
#       6         #cehck if all variables are non-empty
#       7         elif not all([name,planet_type,star]):
# ----> 8             raise ValueError('name, planet_type, and star must be non-empty strings')
#       9         else:
#      10             self.name = name
#
# ValueError: name, planet_type, and star must be non-empty strings

# %% [markdown]
# # Test 9

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name
            self.planet_type = planet_type
            self.star = star

    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...'

    def __str__(self):
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'


planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-610921188.py in <cell line: 0>()
#      21 planet_1 = Planet('Earth','Terrestrial','Sun')
#      22 planet_2 = Planet('Jupiter','Gas','Sun')
# ---> 23 planet_3 = Planet('Neptune','Ice Giant','')
#      24 #Print __str__ method
#      25 print(planet_1)
#
# /tmp/ipython-input-610921188.py in __init__(self, name, planet_type, star)
#       6         #cehck if all variables are non-empty
#       7         elif not all([name,planet_type,star]):
# ----> 8             raise ValueError('name, planet_type, and star must be non-empty strings')
#       9         else:
#      10             self.name = name
#
# ValueError: name, planet_type, and star must be non-empty strings

# %% [markdown]
# # Test 10 - 12

# %%
self.name = name #Test 10
self.planet_type = planet_type # Test 11
self.star = star # Test 12

# %% [markdown]
# # Test 13-14

# %%
# Test 13
def orbit(self):#defining orbit method
  return f'{self.name} is orbiting around {self.star}...' #Test 14

# %% [markdown]
# # Test 15-16

# %%
def __str__(self):#Test 15
  return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'#Test 16

# %% [markdown]
# # Test 17

# %%
#Test 17
planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')

# %%
class Planet: #creating empty class object
    def __init__(self,name,planet_type,star):#initializing instance
        if not all(isinstance(entry,str) for entry in [name,planet_type,star]):
            raise TypeError(f'name, planet type, and star must be strings')

        #cehck if all variables are non-empty
        elif not all([name,planet_type,star]):
            raise ValueError('name, planet_type, and star must be non-empty strings')
        else:
            self.name = name #Test 10
            self.planet_type = planet_type # Test 11
            self.star = star # Test 12
    # Test 13
    def orbit(self):#defining orbit method
        return f'{self.name} is orbiting around {self.star}...' #Test 14

    def __str__(self):#Test 15
        return f'Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}'#Test 16

#Test 17
planet_1 = Planet('Earth','Terrestrial','Sun')
planet_2 = Planet('Jupiter','Gas','Sun')
planet_3 = Planet('Neptune','Ice Giant','Sun')
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)

#PrintOrbit Method
planet_1.orbit()
planet_2.orbit()
planet_3.orbit()



#Object Location In Memory
print(hex(id(planet_1)))
print(hex(id(planet_2)))
print(hex(id(planet_3)))

# %% [markdown]
# # Test 18

# %%
#Print __str__ method
print(planet_1)
print(planet_2)
print(planet_3)
# Out:
# Planet: Earth | Type: Terrestrial | Star: Sun
# Planet: Jupiter | Type: Gas | Star: Sun
# Planet: Neptune | Type: Ice Giant | Star: Sun
# 0x7fdaed681a90
# 0x7fdaed8000e0
# 0x7fdaed800290

# %% [markdown]
# # Test 19

# %%
#PrintOrbit Method
print(planet_1.orbit())
print(planet_2.orbit())
print(planet_3.orbit())
# Out:
# Earth is orbiting around Sun...
# Jupiter is orbiting around Sun...
# Neptune is orbiting around Sun...
