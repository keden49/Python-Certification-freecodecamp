# %%
# Attempting to join lists with spaces in between

rods = [[],[],[3,2,1]]
spaced_lists = ' '.join(str(rod) for rod in rods)
print(spaced_lists)
# Out:
# [] [] [3, 2, 1]

# %%
# Attempting to move disks
#pop method moves last elements
rods = [1],[],[3,2]
rods[2].append(rods[0].pop())

print(rods)
# Out:
# ([], [], [3, 2, 1])

# %%
for k in range(1,3):
  print(k)
# Out:
# 1
# 2

# %%
# attempting to create disks inside a function when one argument is passed


def hanoi_solver(n):
  if n < 0:
    return None
  rod1 = [k for k in range(1,n+1)][::-1]#reverses the order of the list
  rod2 = []
  rod3 = []

  return rod1

# %%
print(hanoi_solver(-1))
# Out:
# None

# %%
# Attempting to move 1 when its the only disk
def hanoi_solver(n):
  rods = [[k for k in range(1,n+1)][::-1],[],[]]

  if n == 1:
    rods[2].append(rods[0].pop())
  return ' '.join(str(rod) for rod in rods)#return initial state

# %%
hanoi_solver(1)
# Out:
# '[] [] [1]'

# %%
hanoi_solver(3)
# Out:
# '[3, 2, 1] [] []'

# %%
hanoi_solver(6)
# Out:
# '[6, 5, 4, 3, 2, 1] [] []'

# %% [markdown]
# # Logic
#
# Get n-1 rods to the other rod from the starting position this will always be the case
#
# other can be calculated in terms of 6 - (starting position + end position)
#
# n(base) should always move to the end rod.
#
# Recursively means each time the function is called (n-1) becomes the new n
#
# In a single recursive call top_disk has 2 plays/moves while bottom disk has 1

# %%
#how will I be able to track positions recursively ?
#goal is to move 1 from
#[3,2,1] to other list depending calculations
# a function, that prints each move

def hanoi_solver(n):
  rods = [[k for k in range(1,n+1)][::-1],[],[]]

  if n == 1:
    rods[2].append(rods[0].pop())

  else:
    # Goal first item in initial list to end in the final list
    #rod2.append(rod[0][0])
    #to do so disks on top of it must be removed
    #what controls the game is the position of the rods
    #if I pass [3,2,1] the end result should be 1 moved to the end



    other = (6-(start + end))


  #return ' '.join(str(rod) for rod in rods)#return initial state

# %%
def hanoi(n, start, end):
    if n == 1: print(start, end)
    else:
        other = 6 - (start + end)
        hanoi(n-1, start, other)
        print(start, end)
        hanoi(n-1, other, end)

# %%
print(hanoi(3,1,3))
# Out:
# 1 3
# 1 2
# 3 2
# 1 3
# 2 1
# 2 3
# 1 3
# None
